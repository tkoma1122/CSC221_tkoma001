# %%
print('Hello Python world!')
# Out:
# Hello Python world!

# %%
message = "Hello Python world!"
print(message)

message = "Hello Python Crash Course World!"
print(message)
# Out:
# Hello Python world!
# Hello Python Crash Course World!

# %%
message = "Hello Python Crash Course World!"
print(mesage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6a3d6a7072ab> in <cell line: 2>()
#       1 message = "Hello Python Crash Course World!"
# ----> 2 print(mesage)
#
# NameError: name 'mesage' is not defined

# %%
mesage = "Hello Python Crash Course World!"
print(mesage)
# Out:
# Hello Python Crash Course World!

# %% [markdown]
# Try it yourself 2-1, 2-2

# %%
message = "I am working on the basic Python Coding!"
print(message)

newmessage = "Now I changed the value of the variable"
print(newmessage)
# Out:
# I am working on the basic Python Coding!
# Now I changed the value of the variable

# %%
"This is a string"
'This is also a string'
# Out:
# 'This is also a string'

# %%
'I told my friend, "Python is my language!"'
"The language 'Python' is named after Monty Python, not the snake."
"One of Python's strengths is its diverse and supportive community."
# Out:
# "One of Python's strengths is its diverse and supportive community."

# %%
name = "ada lovelace"
print(name.title())
# Out:
# Ada Lovelace

# %%
name = "Ada Lovelace"
print(name.upper())
print(name.lower())
# Out:
# ADA LOVELACE
# ada lovelace

# %%
first_name = "ada"
last_name = "lovelace"
full_name = f"{first_name} {last_name}"
print(full_name)
# Out:
# ada lovelace

# %%
first_name = "ada"
last_name = "lovelace"
full_name = f"{first_name} {last_name}"
print(f"Hello, {full_name.title()}")
# Out:
# Hello, Ada Lovelace

# %%
first_name = "ada"
last_name = "lovelace"
full_name = f"{first_name} {last_name}"
message = f"Hello, {full_name.title()}!"
print(message)
# Out:
# Hello, Ada Lovelace!

# %%
print("Python")
print("\tPython")
# Out:
# Python
# 	Python

# %%
print("Languages:\nPython\nC\nJavaScript")
# Out:
# Languages:
# Python
# C
# JavaScript

# %%
print("Languages:\n\tPython\n\tC\n\tJavaScript")
# Out:
# Languages:
# 	Python
# 	C
# 	JavaScript

# %%
favorite_language = 'python '
favorite_language
favorite_language.rstrip()
favorite_language
favorite_language = favorite_language.rstrip()
favorite_language
# Out:
# 'python'

# %%
favorite_language = ' python '
favorite_language.rstrip()
favorite_language.lstrip()
favorite_language.strip()
# Out:
# 'python'

# %%
nostarch_url = 'https://nostarch.com'
nostarch_url.removeprefix('https://')
# Out:
# 'nostarch.com'

# %%
simple_url = nostarch_url.removeprefix('https://')

# %%
message = "One of Python's strengths is its diverse community."
print(message)
# Out:
# One of Python's strengths is its diverse community.

# %%
message = 'One of Python's strengths is the diverse community'
# Out:
#   File "<ipython-input-43-1b0d75c704c5>", line 1
#     message = 'One of Python's strengths is the diverse community'
#                                                                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Try it yourself 2-3 to 8

# %%
name_sample = "eric"
message = f"Hello, {name_sample.title()}, would you like to learn some Python today?"
print(message)
# Out:
# Hello, Eric, would you like to learn some Python today?

# %%
name = "Eric"
print(name.upper())
print(name.lower())
print(name.title())
# Out:
# ERIC
# eric
# Eric

# %%
quote = '"Parting is such sweet sorrow"'
sentence = f"William Shakespeare said, {quote.strip()}."
print(sentence)
# Out:
# William Shakespeare said, "Parting is such sweet sorrow".

# %%
quote = '"Parting is such sweet sorrow"'
famous_person = "William Shakespeare"
message = f"{famous_person()} 'said,' {quote.strip()}."
print(message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-48d34bc6625f> in <cell line: 3>()
#       1 quote = '"Parting is such sweet sorrow"'
#       2 famous_person = "William Shakespeare"
# ----> 3 message = f"{famous_person()} 'said,' {quote.strip()}."
#       4 print(message)
#
# TypeError: 'str' object is not callable

# %%
name = "\tTaichi Komai\t"
print(name)
# Out:
# 	Taichi Komai

# %%
name = " Taichi Komai "
name.rstrip()
# Out:
# ' Taichi Komai'

# %%
name = " Taichi Komai "
name.lstrip()
# Out:
# 'Taichi Komai '

# %%
name = " Taichi Komai "
name.strip()
# Out:
# 'Taichi Komai'

# %%
url = 'python_note.txt'
url.removesuffix('.txt')
# Out:
# 'python_note'

# %%
2 + 3
# Out:
# 5

# %%
3 - 2
# Out:
# 1

# %%
2 * 3
# Out:
# 6

# %%
3 / 2
# Out:
# 1.5

# %%
3 ** 2
# Out:
# 9

# %%
3 ** 3
# Out:
# 27

# %%
10 ** 6
# Out:
# 1000000

# %%
2 + 3*4
# Out:
# 14

# %%
(2 + 3) * 4
# Out:
# 20

# %%
0.1 + 0.1
# Out:
# 0.2

# %%
0.2 + 0.2
# Out:
# 0.4

# %%
2 * 0.1
# Out:
# 0.2

# %%
2 * 0.2
# Out:
# 0.4

# %%
0.2 + 0.1
# Out:
# 0.30000000000000004

# %%
3 * 0.1
# Out:
# 0.30000000000000004

# %%
4/2
# Out:
# 2.0

# %%
1 + 2.0
# Out:
# 3.0

# %%
2 * 3.0
# Out:
# 6.0

# %%
3.0 ** 2
# Out:
# 9.0

# %%
universe_age = 14_000_000_000
print(universe_age)
# Out:
# 14000000000

# %%
x, y, z = 0, 0, 0

# %%
MAX_CONNECTIONS = 5000

# %% [markdown]
# TRY IT YOURSELF

# %%
print(5+3)
# Out:
# 8

# %%
favorite_number = '"23"'
message = f"My favorite number is {favorite_number()}"
print(message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-96ad6616c79b> in <cell line: 2>()
#       1 favorite_number = '"23"'
# ----> 2 message = f"My favorite number is {favorite_number()}"
#       3 print(message)
#
# TypeError: 'str' object is not callable

# %%
# Say hello to everyone.
print("Hello Python people")
# Out:
# Hello Python people

# %%
#Print the comment that we entered.
comment = "Hello World!"
print(comment)
#Print and compute the number that we entered.
3578312 * 3
# Out:
# Hello World!
# 10734936

# %%
import this
The Zen of Python, by Tim Peters
Beautiful is better than ugly.
Simple is better than complex.
Complex is better than complicated.
Readability counts.
There should be one-- and preferably only one --obvious way to do it.
Now is better than never.

# %% [markdown]
# TRY IT YOURSELF

# %%
import this
The Zen of Python, by Tim Peters
